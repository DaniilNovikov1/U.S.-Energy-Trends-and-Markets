# %%
"""
In this file, we will take a look at broad trends and correlations. These include comparing overall 
energy production, consumption, and distribution with the market as a whole and specific sectors.
"""

# %%
# import functions and classes from our functions.py file we created during out data transformation process
from functions import energy_data_file_reference_function, folder_path, sheets_to_dataframes, table_transformer, transformed_energy_data

# %%
# create class with all our data
# folder_path to our data
folder_path = "C:/Users/danii/OneDrive/Desktop/Energy Data Files"

# run functions to get our data
energy_data_file_reference_function(folder_path)
transformed_energy_data()

# %%
# view all transformed DataFrames we can access from our class
class_directory = list(filter(lambda x: not x.startswith("_"), dir(transformed_energy_data)))
print(class_directory)
# Out:
# ['biofuel_prod', 'biomass_consump', 'coal_consump', 'coal_expend', 'coal_prices', 'coal_prod', 'commer_consump', 'commer_consump_percap', 'commer_expend', 'commer_prices', 'crude_prod', 'elec_expend', 'elec_prices', 'ener_consump_per_realgdp', 'geother_consump', 'hydro_consump', 'indust_consump', 'indust_consump_percap', 'indust_expend', 'indust_prices', 'motogas_expend', 'motogas_expend_percap', 'motogas_prices', 'natgas_consump', 'natgas_expend', 'natgas_prices', 'natgas_prod', 'np', 'nuclear_consump', 'nuclear_prod', 'other_renew_prod', 'petro_consump', 'petro_expend', 'petro_prices', 'realgdp2', 'reduce', 'resid_consump', 'resid_consump_percap', 'resid_elec_sales', 'resid_elec_sales_percap', 'resid_expend', 'resid_prices', 'solar_consump', 'tot_consump', 'tot_ener_prod', 'tot_expend', 'tot_expend_percap', 'tot_expend_pergdp', 'tot_expend_prices', 'tot_prime_consump', 'tot_prime_prod', 'tot_renew_consump', 'tot_renew_prod', 'tot_ret_elec_sales', 'tot_ret_elec_sales_percap', 'tot_s
# ...

# %%
# view total energy production
transformed_energy_data.tot_ener_prod
# Out:
# Total energy production, billion Btu  Year     Alaska    Alabama   Arkansas  \
# 0                                     1960    21554.0   474228.0   289299.0
# 1                                     1961    56144.0   474778.0   291209.0
# 2                                     1962    82748.0   484723.0   282213.0
# 3                                     1963    87933.0   469027.0   284502.0
# 4                                     1964    90198.0   541262.0   281323.0
# ..                                     ...        ...        ...        ...
# 56                                    2016  1435363.0  1118407.0  1127828.0
# 57                                    2017  1454196.0  1230179.0   989005.0
# 58                                    2018  1410604.0  1245875.0   888125.0
# 59                                    2019  1370342.0  1250624.0   837386.0
# 60                                    2020  1348969.0  1205912.0   782360.0
#
# ...
